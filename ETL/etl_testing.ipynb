# %% [markdown]
# # Imports & Setup

# %%
import polars as pl

# %% [markdown]
# # Data Cleaning

# %%
companies = pl.read_parquet('data/raw/parquet/companies.parquet')
share_prices = pl.read_parquet('data/raw/parquet/share_prices.parquet')

# %%
with pl.Config(tbl_rows=25):
    display(companies.drop_nulls(subset=pl.col('Number Employees')).sort('Number Employees', descending=True).head(25))
# Out:
# shape: (25, 10)
# ┌──────────┬────────────┬────────────┬────────────┬───┬───────────┬────────┬───────────┬───────────┐
# │ SimFinId ┆ Company    ┆ IndustryId ┆ ISIN       ┆ … ┆ Business  ┆ Market ┆ CIK       ┆ Main      │
# │ ---      ┆ Name       ┆ ---        ┆ ---        ┆   ┆ Summary   ┆ ---    ┆ ---       ┆ Currency  │
# │ i64      ┆ ---        ┆ f64        ┆ str        ┆   ┆ ---       ┆ str    ┆ f64       ┆ ---       │
# │          ┆ str        ┆            ┆            ┆   ┆ str       ┆        ┆           ┆ str       │
# ╞══════════╪════════════╪════════════╪════════════╪═══╪═══════════╪════════╪═══════════╪═══════════╡
# │ 62747    ┆ AMAZON COM ┆ 103002.0   ┆ US02313510 ┆ … ┆ Amazon.co ┆ us     ┆ 1.018724e ┆ USD       │
# │          ┆ INC        ┆            ┆ 67         ┆   ┆ m Inc is  ┆        ┆ 6         ┆           │
# │          ┆            ┆            ┆            ┆   ┆ an online ┆        ┆           ┆           │
# ...

# %%
with pl.Config(tbl_rows=25):
    display(share_prices.head(25))
# Out:
# shape: (25, 9)
# ┌──────────┬────────┬────────┬────────┬───┬────────────┬───────────┬──────────┬────────────────────┐
# │ SimFinId ┆ Open   ┆ High   ┆ Low    ┆ … ┆ Adj. Close ┆ Volume    ┆ Dividend ┆ Shares Outstanding │
# │ ---      ┆ ---    ┆ ---    ┆ ---    ┆   ┆ ---        ┆ ---       ┆ ---      ┆ ---                │
# │ i64      ┆ f64    ┆ f64    ┆ f64    ┆   ┆ f64        ┆ i64       ┆ f64      ┆ f64                │
# ╞══════════╪════════╪════════╪════════╪═══╪════════════╪═══════════╪══════════╪════════════════════╡
# │ 45846    ┆ 118.9  ┆ 120.29 ┆ 117.09 ┆ … ┆ 118.11     ┆ 2650429   ┆ null     ┆ 2.82602317e8       │
# │ 367153   ┆ 61.12  ┆ 63.45  ┆ 58.65  ┆ … ┆ 60.38      ┆ 7253326   ┆ null     ┆ 2.63839742e8       │
# │ 7962652  ┆ 10.77  ┆ 10.79  ┆ 10.77  ┆ … ┆ 10.79      ┆ 599704    ┆ null     ┆ 9.8498541e7        │
# │ 18959140 ┆ 10.34  ┆ 10.34  ┆ 10.34  ┆ … ┆ 10.34      ┆ 7         ┆ null     ┆ null               │
# ...
